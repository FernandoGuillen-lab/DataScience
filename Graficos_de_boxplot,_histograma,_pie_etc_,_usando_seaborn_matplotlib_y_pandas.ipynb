# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandoGuillen-lab/DataScience/blob/main/Graficos_de_boxplot%2C_histograma%2C_pie_etc_%2C_usando_seaborn_matplotlib_y_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DS_C3_SC1 - PLATAFORMAS DE VISUALIZACIÓN**
#
# ---
#
# **Reto: Explorando el índice de felicidad**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# NOMBRE DEL PARTICIPANTE: Fernando Guillén Aldape

# %% [markdown]
# 1.	Genera una libreta en Google Colab para el reto, cuya estructura esté basada en los análisis solicitados.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 2.	Descarga el archivo: happiness_report.csv y guarda, en un dataframe (`happiness`), todos sus registros.

# %%
happiness=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/happiness_report.csv")

happiness
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df=happiness.copy()
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
metadata=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Metadata.csv")

metadata
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFG                  South Asia           Low income
# 2            AGO          Sub-Saharan Africa  Lower middle income
# 3            ALB       Europe & Central Asia  Upper middle income
# 4            AND       Europe & Central Asia          High income
# ..           ...                         ...                  ...
# 258          XKX       Europe & Central Asia  Upper middle income
# 259          YEM  Middle East & North Africa           Low income
# 260          ZAF          Sub-Saharan Africa  Upper middle income
# 261          ZMB          Sub-Saharan Africa  Lower middle income
# 262          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes     TableName
# 0                                                  NaN         Aruba
# ...

# %%
m1=metadata.copy()
m1=m1.rename(columns={"TableName":"Country or region"})
m1
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFG                  South Asia           Low income
# 2            AGO          Sub-Saharan Africa  Lower middle income
# 3            ALB       Europe & Central Asia  Upper middle income
# 4            AND       Europe & Central Asia          High income
# ..           ...                         ...                  ...
# 258          XKX       Europe & Central Asia  Upper middle income
# 259          YEM  Middle East & North Africa           Low income
# 260          ZAF          Sub-Saharan Africa  Upper middle income
# 261          ZMB          Sub-Saharan Africa  Lower middle income
# 262          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes Country or region
# 0                                                  NaN             Aruba
# ...

# %% [markdown]
# 3.	A partir del dataframe happiness obtén otro (`mexico`) donde sólo almacenes la información de México. Haz que la columna `Country or region` quede como índice.

# %%
mexico=happiness.loc[happiness["Country or region"]== "Mexico"]
mexico.set_index("Country or region", inplace=True)

mexico
# Out:
#                    Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Mexico                       23  6.595            1.07           1.323
#
#                    Healthy life expectancy  Freedom to make life choices  \
# Country or region
# Mexico                               0.861                         0.433
#
#                    Generosity  Perceptions of corruption
# Country or region
# Mexico                  0.074                      0.073

# %% [markdown]
# 4.	Obtén un histograma del puntaje (`score`) para identificar el rango o clase más frecuente. Ubica el valor de México con una etiqueta de texto.

# %%
happiness['Score'].plot.hist(color="g")
plt.title("World Happiness Report")
plt.xlabel("Score")
configuracion={"boxstyle":"circle","facecolor":"red","alpha":0.3}
confi={"size":10,"weight":"bold","color":"white"}
plt.text(6.595,0,"MEX",bbox=configuracion, fontdict=confi)
# Out:
# Text(6.595, 0, 'MEX')

# %% [markdown]
# 5.	Construye un box plot para la columna esperanza de vida (`Healthy life expectancy`). Ubica el valor de México con una anotación.

# %%
happiness['Healthy life expectancy'].plot.box(color="g")
plt.title("World Happiness Report")
configuracion={"boxstyle":"circle","facecolor":"red","alpha":0.3}
confi={"size":10,"weight":"bold","color":"white"}
plt.text(1.2,0.861,"MEX",bbox=configuracion, fontdict=confi)
plt.annotate("",xy=(1,0.861),xytext=(1.19,0.861),arrowprops=dict(arrowstyle="->"))
# Out:
# Text(1.19, 0.861, '')

# %% [markdown]
# 6.	Crea una gráfico circular para analizar en qué medida los factores contribuyen a evaluar la felicidad en México. Para ello, deberás modificar la estructura del dataframe `mexico` obtenido anteriormente.

# %%
mexico1=mexico.T
mexico1=mexico1.iloc[2:]
mexico1.rename(columns={"Mexico":"Factors"},inplace=True)
mexico1.index.name=None
mexico1
# Out:
# Country or region             Factors
# GDP per capita                  1.070
# Social support                  1.323
# Healthy life expectancy         0.861
# Freedom to make life choices    0.433
# Generosity                      0.074
# Perceptions of corruption       0.073

# %%
mexico1['Factors'].plot.pie(ylabel="",autopct="%1.1f%%")
plt.title("Contribution in Mexico happiness score")
# Out:
# Text(0.5, 1.0, 'Contribution in Mexico happiness score')

# %% [markdown]
# 7.	Filtra el dataframe para quedarte con 5 países (el más feliz, el menos feliz, México y dos más de tu interés) y visualiza en una misma gráfica los 6 factores.

# %%
paises=["Finland","United States","Mexico","China","South Sudan"]
filtro=happiness[happiness["Country or region"].isin(paises)]
filtro.set_index("Country or region", inplace=True)
filtro=filtro.drop(["Overall rank","Score"],axis=1)
filtro=filtro.T
filtro
# Out:
# Country or region             Finland  United States  Mexico  China  \
# GDP per capita                  1.340          1.433   1.070  1.029
# Social support                  1.587          1.457   1.323  1.125
# Healthy life expectancy         0.986          0.874   0.861  0.893
# Freedom to make life choices    0.596          0.454   0.433  0.521
# Generosity                      0.153          0.280   0.074  0.058
# Perceptions of corruption       0.393          0.128   0.073  0.100
#
# Country or region             South Sudan
# GDP per capita                      0.306
# Social support                      0.575
# Healthy life expectancy             0.295
# Freedom to make life choices        0.010
# Generosity                          0.202
# Perceptions of corruption           0.091

# %%
filtro.plot.bar()
plt.title("World Happiness Report")
# Out:
# Text(0.5, 1.0, 'World Happiness Report')

# %% [markdown]
# 8.	Crea una matriz de subgráficas de 2 x 3 con scatter plots del puntaje (`score`) versus los 6 factores para determinar qué factor influye más en la evaluación.

# %%
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
fig=plt.figure(figsize=(20,10))
fig.suptitle("Contribution in happiness score",fontsize=18)
ax1=fig.add_subplot(231)
ax1=sns.scatterplot(x="Score",y="GDP per capita",c="green", data=df)
ax2=fig.add_subplot(232)
ax2=sns.scatterplot(x="Score",y="Social support",c="green", data=df)
ax3=fig.add_subplot(233)
ax3=sns.scatterplot(x="Score",y="Healthy life expectancy",c="green", data=df)
ax4=fig.add_subplot(234)
ax4=sns.scatterplot(x="Score",y="Freedom to make life choices",c="green", data=df)
ax5=fig.add_subplot(235)
ax5=sns.scatterplot(x="Score",y="Generosity",c="green", data=df)
ax6=fig.add_subplot(236)
ax6=sns.scatterplot(x="Score",y="Perceptions of corruption",c="green", data=df)

# %% [markdown]
# 9.	Comprueba lo anterior con un heatmap donde incluyas los índices de correlación.

# %%
sns.heatmap(round(df.corr(),2),annot=True)
# Out:
# <ipython-input-144-a2dd9426b4c5>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(round(df.corr(),2),annot=True)
# <Axes: >

# %% [markdown]
# 10.	Combina con el dataframe `metada` (Metadata.csv) para graficar la felicidad promedio por región.

# %%
df2=pd.merge(df,m1,on=["Country or region"],how="outer")
df2
# Out:
#      Overall rank      Country or region  Score  GDP per capita  \
# 0             1.0                Finland  7.769           1.340
# 1             2.0                Denmark  7.600           1.383
# 2             3.0                 Norway  7.554           1.488
# 3             4.0                Iceland  7.494           1.380
# 4             5.0            Netherlands  7.488           1.396
# ..            ...                    ...    ...             ...
# 278           NaN  Virgin Islands (U.S.)    NaN             NaN
# 279           NaN                Vanuatu    NaN             NaN
# 280           NaN                  World    NaN             NaN
# 281           NaN                  Samoa    NaN             NaN
# 282           NaN            Yemen, Rep.    NaN             NaN
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
sns.barplot(x="Region",y="Score",data=df2)
plt.xticks(rotation=90)
plt.title("World Happiness Report")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# Text(0.5, 1.0, 'World Happiness Report')
